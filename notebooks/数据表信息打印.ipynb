# %%
import sqlalchemy
from sqlalchemy import create_engine, MetaData
import config
from utils import setup_logging

def describe_database_schema():
    """
    连接到数据库，通过反射获取并打印所有表的结构信息。
    """
    # 1. 设置日志（可选，但保持好习惯）
    logger = setup_logging('database_schema.log')
    logger.info("开始执行数据库结构描述任务...")

    # 2. 连接数据库
    try:
        db_uri = f"postgresql+psycopg2://{config.DB_USER}:{config.DB_PASS}@{config.DB_HOST}:{config.DB_PORT}/{config.DB_NAME}"
        engine = create_engine(db_uri)
        logger.info("数据库连接成功。")
    except Exception as e:
        logger.critical("数据库连接失败: %s", e, exc_info=True)
        return

    # 3. 执行反射的核心步骤
    try:
        meta = MetaData()
        # 一行代码完成所有表的结构加载
        meta.reflect(bind=engine)
        logger.info("成功从数据库反射表结构。")

        # 4. 格式化输出
        print("--- 数据库结构报告 ---")
        if not meta.tables:
            print("数据库中没有找到任何表。")
            logger.warning("数据库中没有找到任何表。")
        
        for table_name, table in meta.tables.items():
            print(f"\n表名 (Table): {table_name}")
            print("-" * (len(table_name) + 15))
            for column in table.columns:
                col_info = (
                    f"  - 列名 (Column): {column.name}\n"
                    f"    数据类型 (Type): {column.type}\n"
                    f"    主键? (Primary Key?): {column.primary_key}\n"
                    f"    允许为空? (Nullable?): {column.nullable}"
                )
                print(col_info)
        
        print("\n--- 报告结束 ---")
        logger.info("数据库结构报告生成完毕。")

    except Exception as e:
        logger.error("反射数据库结构时发生错误: %s", e, exc_info=True)

if __name__ == '__main__':
    describe_database_schema()
# Out:
# 2025-06-12 06:52:01 - MyQuantProject - INFO - 开始执行数据库结构描述任务...
# 2025-06-12 06:52:01 - MyQuantProject - INFO - 数据库连接成功。
# 2025-06-12 06:52:01 - MyQuantProject - INFO - 成功从数据库反射表结构。
# 2025-06-12 06:52:01 - MyQuantProject - INFO - 数据库结构报告生成完毕。
# --- 数据库结构报告 ---
#
# 表名 (Table): stock_daily_data
# -------------------------------
#   - 列名 (Column): ts_code
#     数据类型 (Type): VARCHAR(15)
#     主键? (Primary Key?): True
#     允许为空? (Nullable?): False
#   - 列名 (Column): trade_date
#     数据类型 (Type): DATE
#     主键? (Primary Key?): True
#     允许为空? (Nullable?): False
#   - 列名 (Column): open
#     数据类型 (Type): NUMERIC(10, 2)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): high
#     数据类型 (Type): NUMERIC(10, 2)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): low
#     数据类型 (Type): NUMERIC(10, 2)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): close
#     数据类型 (Type): NUMERIC(10, 2)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): pre_close
#     数据类型 (Type): NUMERIC(10, 2)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): change
#     数据类型 (Type): NUMERIC(10, 2)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): pct_chg
#     数据类型 (Type): NUMERIC(8, 4)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): vol
#     数据类型 (Type): BIGINT
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): amount
#     数据类型 (Type): NUMERIC(18, 3)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#
# 表名 (Table): stock_beta_values
# --------------------------------
#   - 列名 (Column): ts_code
#     数据类型 (Type): VARCHAR(15)
#     主键? (Primary Key?): True
#     允许为空? (Nullable?): False
#   - 列名 (Column): benchmark_ts_code
#     数据类型 (Type): VARCHAR(15)
#     主键? (Primary Key?): True
#     允许为空? (Nullable?): False
#   - 列名 (Column): start_date
#     数据类型 (Type): DATE
#     主键? (Primary Key?): True
#     允许为空? (Nullable?): False
#   - 列名 (Column): end_date
#     数据类型 (Type): DATE
#     主键? (Primary Key?): True
#     允许为空? (Nullable?): False
#   - 列名 (Column): beta
#     数据类型 (Type): NUMERIC(10, 4)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): num_observations
#     数据类型 (Type): INTEGER
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): calculation_status
#     数据类型 (Type): VARCHAR(255)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): calculation_run_date
#     数据类型 (Type): TIMESTAMP
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#
# 表名 (Table): stock_basic_info
# -------------------------------
#   - 列名 (Column): ts_code
#     数据类型 (Type): TEXT
#     主键? (Primary Key?): True
#     允许为空? (Nullable?): False
#   - 列名 (Column): name
#     数据类型 (Type): TEXT
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): False
#   - 列名 (Column): industry
#     数据类型 (Type): TEXT
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): market
#     数据类型 (Type): TEXT
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): list_date
#     数据类型 (Type): TEXT
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#
# 表名 (Table): stock_cap_classification
# ---------------------------------------
#   - 列名 (Column): ts_code
#     数据类型 (Type): VARCHAR(10)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): name
#     数据类型 (Type): VARCHAR(50)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): industry
#     数据类型 (Type): VARCHAR(50)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): period_start_date
#     数据类型 (Type): DATE
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): period_end_date
#     数据类型 (Type): DATE
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): avg_total_mv
#     数据类型 (Type): NUMERIC(20, 4)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): classification
#     数据类型 (Type): VARCHAR(20)
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#
# 表名 (Table): stock_financial_indicators
# -----------------------------------------
#   - 列名 (Column): ts_code
#     数据类型 (Type): TEXT
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ann_date
#     数据类型 (Type): TEXT
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): end_date
#     数据类型 (Type): TEXT
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): eps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): dt_eps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): total_revenue_ps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): revenue_ps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): capital_rese_ps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): surplus_rese_ps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): undist_profit_ps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): extra_item
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): profit_dedt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): gross_margin
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): current_ratio
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): quick_ratio
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): cash_ratio
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ar_turn
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ca_turn
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): fa_turn
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): assets_turn
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): op_income
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ebit
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ebitda
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): fcff
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): fcfe
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): current_exint
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): noncurrent_exint
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): interestdebt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): netdebt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): tangible_asset
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): working_capital
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): networking_capital
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): invest_capital
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): retained_earnings
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): diluted2_eps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): bps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ocfps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): retainedps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): cfps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ebit_ps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): fcff_ps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): fcfe_ps
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): netprofit_margin
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): grossprofit_margin
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): cogs_of_sales
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): expense_of_sales
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): profit_to_gr
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): saleexp_to_gr
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): adminexp_of_gr
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): finaexp_of_gr
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): impai_ttm
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): gc_of_gr
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): op_of_gr
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ebit_of_gr
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roe
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roe_waa
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roe_dt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roa
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): npta
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roic
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roe_yearly
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roa2_yearly
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): debt_to_assets
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): assets_to_eqt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): dp_assets_to_eqt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ca_to_assets
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): nca_to_assets
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): tbassets_to_totalassets
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): int_to_talcap
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): eqt_to_talcapital
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): currentdebt_to_debt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): longdeb_to_debt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ocf_to_shortdebt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): debt_to_eqt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): eqt_to_debt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): eqt_to_interestdebt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): tangibleasset_to_debt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): tangasset_to_intdebt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): tangibleasset_to_netdebt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ocf_to_debt
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): turn_days
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roa_yearly
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roa_dp
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): fixed_assets
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): profit_to_op
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): q_saleexp_to_gr
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): q_gc_to_gr
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): q_roe
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): q_dt_roe
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): q_npta
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): q_ocf_to_sales
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): basic_eps_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): dt_eps_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): cfps_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): op_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ebt_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): netprofit_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): dt_netprofit_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): ocf_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): roe_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): bps_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): assets_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): eqt_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): tr_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): or_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): q_sales_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): q_op_qoq
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#   - 列名 (Column): equity_yoy
#     数据类型 (Type): DOUBLE PRECISION
#     主键? (Primary Key?): False
#     允许为空? (Nullable?): True
#
# --- 报告结束 ---
